# %%
from __future__ import annotations

import pyvista as pv

pl = pv.Plotter()
pl.add_mesh(pv.Sphere())
app = pl.trame.app()
app

# %%
pl.trame.export_wazex('sphere.wazex')

# %%
pl.trame.export_wasm_html('sphere_wasm.html')
